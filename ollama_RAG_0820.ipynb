# %%
# !pip install PyPDF2
# !pip install pyhwp
# !pip install pytesseract
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: pytesseract in ./anaconda3/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in ./anaconda3/lib/python3.11/site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in ./anaconda3/lib/python3.11/site-packages (from pytesseract) (9.4.0)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.11/site-packages (2.29.0)
# Requirement already satisfied: beautifulsoup4 in ./anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.4)

# %%
import os 
import faiss
import numpy as np
import requests
import json
from PyPDF2 import PdfReader
import subprocess
from tqdm import tqdm
import pytesseract
from PIL import Image
import zipfile
import xml.etree.ElementTree as ET
import re
from nltk.tokenize import sent_tokenize

# %%
# OLLAMA API 앤드포인트
OLLAMA_API = "http://localhost:11434/api"

# %%
def get_embedding(text):
    try:
        response = requests.post(f"{OLLAMA_API}/embeddings", 
                                 json={"model": "EEVE-Korean-10.8B", "prompt": text})
        response.raise_for_status()
        return np.array(response.json()['embedding'])
    except Exception as e:
        print(f"Error in get_embedding: {e}")
        return None

def generate_response(prompt):
    try:
        response = requests.post(f"{OLLAMA_API}/generate", 
                                 # temperature 낮은 값으로 설정하여 일관성 증가
                                 json={"model": "EEVE-Korean-10.8B", "prompt": prompt, "temperature": 0.2},  
                                 stream=True)
        response.raise_for_status()
        full_response = ""
        for line in response.iter_lines():
            if line:
                decoded_line = line.decode('utf-8')
                try:
                    json_response = json.loads(decoded_line)
                    if 'response' in json_response:
                        full_response += json_response['response']
                except json.JSONDecodeError:
                    print(f"Invalid JSON: {decoded_line}")
        return full_response
    except Exception as e:
        print(f"Error in generate_response: {e}")
        return None

# %%
# 문서 준비 및 임베딩 형성 : 파일 형식에 따라 다른 형식으로 데이터를 임베딩 해야함

# PDF 임베딩
def read_pdf(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() + "\n"
    return text

# HWP 임베딩
def read_hwp(file_path):
    try:
        result = subprocess.run(['hwp5txt', file_path], capture_output=True, text=True)
        return result.stdout
    except Exception as e:
        print(f"Error reading HWP file: {e}")
        return ""

# 이미지 파일 임베딩
def extract_text_from_image(image_path):
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image, lang='kor')
    return text

# 한글 버젼 ppt. 기본적인 텍스트 추출만 가능. 복잡한 서식, 표, 이미지 등은 처리하지 않음.
def read_hwpx(file_path):
    try:
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            # 'Contents/section0.xml' 파일에서 텍스트 추출
            with zip_ref.open('Contents/section0.xml') as section_file:
                tree = ET.parse(section_file)
                root = tree.getroot()
                
                # 모든 텍스트 노드 추출
                text_nodes = root.findall(".//hp:t", namespaces={'hp': 'http://www.hancom.co.kr/hwpml/2011/paragraph'})
                
                # 텍스트 결합
                full_text = ' '.join(node.text for node in text_nodes if node.text)
                
                # 불필요한 공백 제거
                full_text = re.sub(r'\s+', ' ', full_text).strip()
                
                return full_text
    except Exception as e:
        print(f"Error reading HWPX file: {e}")
        return ""

# %%
def read_file(file_path):
    _, ext = os.path.splitext(file_path)
    try:
        if ext.lower() == '.pdf':
            return read_pdf(file_path)
        elif ext.lower() == '.hwp':
            return read_hwp(file_path)
        elif ext.lower() in ['.jpg', '.png', '.jpeg']:
            return extract_text_from_image(file_path)
        elif ext.lower() in ['.doc', '.docx']:
            return read_doc(file_path)
        elif ext.lower() == '.hwpx':
            return read_hwpx(file_path)
        else:
            with open(file_path, 'r', encoding='utf-8') as f:
                return f.read()
    except Exception as e:
        # 파일명과 오류 메시지를 출력합니다.
        print(f"Error processing file: {file_path} - {str(e)}")
        return None

documents = []
embeddings = []

file_list = os.listdir('/Users/dahyun/Desktop/hallym')
for filename in tqdm(file_list, desc="Processing files"):
    file_path = os.path.join('/Users/dahyun/Desktop/hallym', filename)
    text = read_file(file_path)
    if text:
        embedding = get_embedding(text)
        if embedding is not None:
            documents.append(text)
            embeddings.append(embedding)
if not documents or not embeddings:
    print("No documents or embeddings were processed successfully.")
    exit()
    
def read_doc(file_path):
    import docx2txt
    return docx2txt.process(file_path)
# Out:
# Processing files:  12%|███▍                       | 1/8 [00:03<00:25,  3.66s/it]
# Error processing file: /Users/dahyun/Desktop/hallym/.DS_Store - 'utf-8' codec can't decode byte 0x80 in position 3131: invalid start byte
# Processing files: 100%|███████████████████████████| 8/8 [00:16<00:00,  2.10s/it]

# %%
# 임베딩 결과 확인
documents
# Out:
# ['\n<표>\n\n<표>\n\n',
#  '체육시설 추첨 신청서\n\n\n<표>\n\n※ 신청자 정보는 추첨 관련 공지를 할 예정이오니, 정확하게 기재하여 주시기 바랍니다.\n',
#  '성 명 전공: 학년: 학번: 자 기 소 개 서 1. 나의 가치관과 목표 2. 나의 전공분야를 선택한 이유와 미래 희망 3. 장학금을 신청한 이유',
#  '《 전공·학과, 단과대학 ·스쿨교학팀 전화번호 , 이메일주소 》\n전화번호 (033-248-_______ ), 이메일주소 ( ________@hallym.ac.kr)\n구분 전화 이메일 구분 전화 이메일\n인문\n대학인문대학 교학팀\n(FAX033-248-1505)1500 de1500\n글로벌\n융합대학글로벌융합대학 교학팀\n(FAX033-248-2485)\n1880 de1880인문학부 - - 글로벌학부\n국어국문학전공 1510 de1510 글로벌비즈니스전공\n철학전공 1550 de1550 정보법과학전공\n사학전공 1570 de1570 한중통번역전공\n영어영문학과 1530 de1530 문화산업전공\n중국학과 1590 de1590 한국학전공\n일본학과 1610 de1610 융합과학수사학과 1980 de1980\n통합스쿨통합스쿨 교학팀\n(FAX033-248-3560)3551 de3550 러시아학과 1630 de1630\n사회\n과학\n대학사회과학대학 교학팀\n(FAX033-248-1702)1700 de1700미디어\n스쿨언론방송융합미디어전공3552~4 de1910디지털미디어콘텐츠전공\n심리학과 1720~1 de1720 반도체⋅\n디 스 플 레 이\n스 쿨반도체전공\n3555 de2050사회학과 1740 de1740 디스플레이전공\n사회복지학부1760,\n1769de1760미래융합\n스쿨디지털인문예술전공\n3556~7 de3553사회복지학전공 글로벌협력전공\n노인복지학전공 융합관광경영전공\n정치행정학과 1780 de1780의약신소재전공\n융합신소재공학전공\n광고홍보학과 1949 de1949\n의과대학의과대학 교학팀\n(FAX033-242-2524) 2501 de2500 법학과 1950 de1950\n경제학과 1810 de1810 의예과 , 의학과\n경영\n대학경영대학 교학팀\n(FAX033-248-1804)1830 de1800간호대학간호대학 교학팀\n(FAX033-248-2734) 2710 de2710\n경영학과 1830 de1830 간호학과\n금융재무학과 1850 de1850 일송기념\n도서관도서관 운영팀 2812\n자연\n과학\n대학자연과학대학 교학팀\n(FAX033-256-3420)2000 de2000\n화학과 2070 de2070\n생명과학과 2090 de2090\n바이오메디컬학과 2110 de2110\n환경생명공학과 2150 de2150\n식품영양학과 2130 de2130\n체육학과 2250 de2250\n언어청각학부 2210~1 -\n언어병리학전공 2210 de2210\n청각학전공 2211 de2211\n정보\n과학\n대학정보과학대학 교학팀\n(FAX033-242-2524)2301 de2300\n소프트웨어학부 - -\n빅데이터전공 , 컴퓨터공학 2310 de2310\n콘 텐 츠 IT전 공, 융 합 소 프 트 웨 어 2330 de2330\n스 마 트 IoT전 공, 전 자 공 학 과 2340 de2340\n인공지능융합학부\n2308~9 de3580AI의료융합전공\nAI로봇융합전공\nAI기술경영융합전공\n데이터사이언스학부\n2306~7 de2030데이터테크전공\n임상의학통계전공\n디지털금융정보전공\n',
#  '(별지서식 1) \n온라인 공개강좌(K-MOOC 등) 학점인정 사전 신청서\n\n<표>\n\n',
#  '붙임 1) 연구보조원 지원 제출서류\n\n\n<표>\n※ 붉은 글씨는 예시이므로, 삭제하고 작성해주세요. \n\n<표>\n\n\n<표>\n\n\n자 기 소 개 서\n\n<표>\n\n\n<표>\n\n위 기재 사항은 사실과 틀림이 없습니다.\n2024년     월     일\n                                 지원자 :                      (서명) \n한림대학교 일본학연구소장 귀하 \n',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\n']

# %%
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm

def extract_text_from_url(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # 페이지에서 불필요한 부분을 제외하고 주요 텍스트를 추출
        for script in soup(["script", "style"]):
            script.extract()  # 자바스크립트와 CSS 제거
        
        text = soup.get_text()
        lines = (line.strip() for line in text.splitlines())
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        text = '\n'.join(chunk for chunk in chunks if chunk)
        
        return text
    except Exception as e:
        print(f"Error extracting text from URL: {url} - {e}")
        return None

# 예시 URL 리스트 (원하는 URL로 변경)
urls = [
    "https://www.hallym.ac.kr/hallym_univ/sub02/cP8/sCP2.html"
]

# 각 URL에서 텍스트를 가져와 documents 리스트에 추가
for url in tqdm(urls, desc="Processing URLs"):
    text = extract_text_from_url(url)
    if text:
        documents.append(text)

# 텍스트 출력 (임베딩 전에 텍스트 확인)
for i, doc in enumerate(documents):
    print(f"Document {i+1}:\n{doc}\n")
# Out:
# Processing URLs: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.85it/s]
# Document 1:
#
# <표>
#
# <표>
#
#
#
# Document 2:
# 체육시설 추첨 신청서
#
#
# <표>
#
# ※ 신청자 정보는 추첨 관련 공지를 할 예정이오니, 정확하게 기재하여 주시기 바랍니다.
#
#
# Document 3:
# 성 명 전공: 학년: 학번: 자 기 소 개 서 1. 나의 가치관과 목표 2. 나의 전공분야를 선택한 이유와 미래 희망 3. 장학금을 신청한 이유
#
# Document 4:
# 《 전공·학과, 단과대학 ·스쿨교학팀 전화번호 , 이메일주소 》
# 전화번호 (033-248-_______ ), 이메일주소 ( ________@hallym.ac.kr)
# 구분 전화 이메일 구분 전화 이메일
# 인문
# 대학인문대학 교학팀
# (FAX033-248-1505)1500 de1500
# 글로벌
# 융합대학글로벌융합대학 교학팀
# (FAX033-248-2485)
# 1880 de1880인문학부 - - 글로벌학부
# 국어국문학전공 1510 de1510 글로벌비즈니스전공
# 철학전공 1550 de1550 정보법과학전공
# 사학전공 1570 de1570 한중통번역전공
# 영어영문학과 1530 de1530 문화산업전공
# 중국학과 1590 de1590 한국학전공
# 일본학과 1610 de1610 융합과학수사학과 1980 de1980
# 통합스쿨통합스쿨 교학팀
# (FAX033-248-3560)3551 de3550 러시아학과 1630 de1630
# 사회
# 과학
# 대학사회과학대학 교학팀
# (FAX033-248-1702)1700 de1700미디어
# 스쿨언론방송융합미디어전공3552~4 de1910디지털미디어콘텐츠전공
# 심리학과 1720~1 de1720 반도체⋅
# 디 스 플 레 이
# 스 쿨반도체전공
# 3555 de2050사회학과 1740 de1740 디스플레이전공
# 사회복지학부1760,
# 1769de1760미래융합
# 스쿨디지털인문예술전공
# 3556~7 de3553사회복지학전공 글로벌협력전공
# 노인복지학전공 융합관광경영전공
# 정치행정학과 1780 de1780의약신소재전공
# 융합신소재공학전공
# 광고홍보학과 1949 de1949
# 의과대학의과대학 교학팀
# (FAX033-242-2524) 2501 de2500 법학과 1950 de1950
# 경제학과 1810 de1810 의예과 , 의학과
# 경영
# 대학경영대학 교학팀
# (FAX033-248-1804)1830 de1800간호대학간호대학 교학팀
# (FAX033-248-2734) 2710 de2710
# 경영학과 1830 de1830 간호학과
# 금융재무학과 1850 de1850 일송기념
# 도서관도서관 운영팀 2812
# 자연
# 과학
# 대학자연과학대학 교학팀
# (FAX033-256-3420)2000 de2000
# 화학과 2070 de2070
# 생명과학과 2090 de2090
# 바이오메디컬학과 2110 de2110
# 환경생명공학과 2150 de2150
# 식품영양학과 2130 de2130
# 체육학과 2250 de2250
# 언어청각학부 2210~1 -
# 언어병리학전공 2210 de2210
# 청각학전공 2211 de2211
# 정보
# 과학
# 대학정보과학대학 교학팀
# (FAX033-242-2524)2301 de2300
# 소프트웨어학부 - -
# 빅데이터전공 , 컴퓨터공학 2310 de2310
# 콘 텐 츠 IT전 공, 융 합 소 프 트 웨 어 2330 de2330
# 스 마 트 IoT전 공, 전 자 공 학 과 2340 de2340
# 인공지능융합학부
# 2308~9 de3580AI의료융합전공
# AI로봇융합전공
# AI기술경영융합전공
# 데이터사이언스학부
# 2306~7 de2030데이터테크전공
# 임상의학통계전공
# 디지털금융정보전공
#
#
# Document 5:
# (별지서식 1)
# 온라인 공개강좌(K-MOOC 등) 학점인정 사전 신청서
#
# <표>
#
#
#
# Document 6:
# 붙임 1) 연구보조원 지원 제출서류
#
#
# <표>
# ※ 붉은 글씨는 예시이므로, 삭제하고 작성해주세요.
#
# <표>
#
#
# <표>
#
#
# 자 기 소 개 서
#
# <표>
#
#
# <표>
#
# 위 기재 사항은 사실과 틀림이 없습니다.
# 2024년     월     일
#                                  지원자 :                      (서명)
# 한림대학교 일본학연구소장 귀하
#
#
# Document 7:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Document 8:
# 교수학습지원 | 한림대학교 > 대학생활 > 프로그램 > 교수학습지원
# 본문바로가기
# 한림대학교 HALLYM UNIVERSITY
# 바로가기메뉴 열기
# 학생정보시스템
# 한림그룹웨어
# 전자출결시스템
# 입학안내
# SmartLEAD
# 한림BeCome
# 인터넷증명발급
# 일송기념도서관
# English
# 中國語
# 글로컬대학
# 발전기금
# Facebook
# Blog
# YouTube
# Instagram
# 학생메일
# 메뉴 열기
# 메뉴 닫기
# English
# 中國語
# 학생메일
# 글로컬대학
# 발전기금
# 대학소개
# 열기
# 총장
# 열기
# 인사말/프로필
# 연설 및 기고
# 동정
# 총장 메시지
# 교육이념과 인재상
# 열기
# 교육이념
# 인재상
# 대학특성화
# 열기
# 대학특성화
# 한림발자취
# 열기
# 연혁
# 자료집
# 역대총장
# 개교 40주년 기념
# - 준비위원회
# - 기념 UI
# - 기념 사업 일정
# 일반현황
# 열기
# 현황
# 조직도
# 규정집
# 예·결산공고/등록금심의위원회
# - 예산공고
# - 결산공고
# - 등록금심의위원회회의록
# 대학평의원회
# 대학자체평가/인증
# - 대학자체평가/인증
# - 대학원자체평가
# 학교법인 현황
# 총장 업무추진비
# 기부금 현황
# 대학상징
# 열기
# 교명
# 교가
# 상징
# UI
# - 서체
# - 40주년 기념 로고
# 안전보건경영방침
# 열기
# 안전보건경영방침
# 캠퍼스 안내
# 열기
# 캠퍼스맵
# 한림비전관
# 캠퍼스 교육환경개선
# 학교오시는길
# 셔틀버스
# New Hallym 혁신본부
# 열기
# D-1
# - 기획팀
# - 전략평가팀
# - 예산팀
# D-2
# - 글로컬대학지원팀
# - 대학혁신사업지원팀
# D-3
# - 조사연구부
# - 성과확산팀
# 행정부서/기관
# 열기
# 교무처
# - 교무팀
# - 교원인사팀
# - 교육혁신센터
# - 융합교육지원센터
# 연구처
# - 연구진흥팀
# 학생처
# - 학생지원팀
# - 취업진로지원센터
# - 현장실습지원센터
# - 학생성장지원센터
# - 한림봉사센터
# - 지역정주지원센터
# - 장애학생지원센터
# 행정지원처
# - 총무팀
# - 구매관재팀
# - 재무팀
# - 시설팀
# - 안전팀
# 대외협력처
# - 커뮤니케이션팀
# - 글로벌교류센터
# 입학처
# - 입학팀
# - 한림인재전형연구실
# 부속기관
# 열기
# 지식미디어센터
# 커뮤니티교육원
# 한림스포츠센터
# 학생생활관
# 정보전산원
# 고령사회종합연구원
# 실험동물센터
# 박물관
# 캠퍼스라이프 카운슬링센터
# 한림학보사
# 직속기구 및 기타기관
# 열기
# 융합클러스터
# - 의료·바이오융합연구원
# - AI융합연구원
# - 한림대학교 도헌학술원
# LINC 3.0 사업단
# 한림청소년자립지원관
# 영어교육센터
# 한국어교육센터
# 의사소통교육센터
# SW중심대학 사업단
# 에듀테크소프트랩 사업단
# 한림과학원
# 태동고전연구소
# 인권센터
# 생명윤리위원회
# 대경강원권역강원지역R-WeSET사업단
# 대학소개
# 글로벌 일류 대학, 한림대학교융·복합 교육을 통해 글로벌 인재를 양성합니다
# 대학/대학원
# 열기
# 인문대학
# 열기
# 인문학부
# 영어영문학과
# 중국학과
# 일본학과
# 러시아학과
# 인문콘텐츠융합전공
# 사회과학대학
# 열기
# 심리학과
# 사회학과
# 사회복지학부
# 정치행정학과
# 광고홍보학과
# 법학과
# 경제학과
# 청소년학
# 경영대학
# 열기
# 경영학과
# 금융재무학과
# 스타트업비즈니스(융합)전공
# 자연과학대학
# 열기
# 화학과
# 생명과학과
# 바이오메디컬학과
# 식품영양학과
# 환경생명공학과
# 언어청각학부
# 체육학과
# 바이오헬스케어융합전공
# 의과대학
# 열기
# 의예·의학과
# 간호대학
# 열기
# 간호학과
# 글로벌융합대학
# 열기
# 글로벌학부
# 융합과학수사학과
# 융합인재학부
# 기후변화융합전공
# MICE기획경영전공
# 미디어스쿨
# 열기
# 언론방송융합미디어 전공
# 디지털미디어콘텐츠 전공
# 반도체·디스플레이스쿨
# 열기
# 반도체전공
# 디스플레이전공
# 정보과학대학
# 열기
# 소프트웨어학부
# 인공지능융합학부
# 데이터사이언스학부
# 미래융합스쿨
# 열기
# 디지털인문예술전공
# 글로벌협력전공
# 융합관광경영전공
# 의약신소재전공
# 융합신소재공학전공
# 마케팅커뮤니케이션테크놀로지융합전공
# 인터랙션디자인전공
# 공공인재융합전공
# 산학협력특성화대학
# 열기
# 지능형 IoT 전공
# - 교육과정 안내
# 사회혁신경영전공
# 건강돌봄디자인 전공
# 일송자유교양대학
# 열기
# 자유교양전공
# 자기설계융합전공
# 열기
# 실감미디어콘텐츠
# 출판기획및실무
# 콘텐츠IT-청각인지헬스케어
# 생명과학AI융합
# 금융경영커뮤니케이션
# 청각인지헬스케어 규제과학
# 글로벌관광커뮤니케이션
# 보험계리학
# 바이오벤처경영
# 대학원
# 열기
# 일반대학원
# 온라인 대학원(창의미래융합대학원)
# 열기
# 디자인·디지털 인문예술학과
# 디지털 마케팅학과
# 특수대학원
# 열기
# 경영대학원
# 사회복지대학원
# 글로벌협력대학원
# 보건과학대학원
# 임상치의학대학원
# 간호대학원
# 대학/대학원
# 글로벌 일류 대학, 한림대학교융·복합 교육을 통해 글로벌 인재를 양성합니다
# 입학
# 열기
# 입학안내
# 열기
# 학부
# 대학원
# 외국인
# 입학
# 글로벌 일류 대학, 한림대학교융·복합 교육을 통해 글로벌 인재를 양성합니다
# 대학생활
# 열기
# 프로그램
# 열기
# 교수학습지원
# 장애학생지원
# 국제교류
# 취업지원
# 병무안내
# 학생활동
# 복지시설
# 장학제도
# 열기
# 신입생장학금
# 재학생장학금
# 학자금 융자
# FAQ
# 캘린더
# 열기
# 학사일정
# 주요일정
# 대학생활 안내
# 열기
# 대학요람
# Hallym Census
# 미디어센터
# 열기
# 한림투데이
# 교직원동정
# 칼럼 및 기고
# 포토갤러리
# 대학민원
# 열기
# FAQ
# 증명서 발급
# 서식/신청서
# 교내홈페이지
# 대학생활
# 글로벌 일류 대학, 한림대학교융·복합 교육을 통해 글로벌 인재를 양성합니다
# 학사지원
# 열기
# 교육과정
# 열기
# 복수전공
# 자기설계융합전공
# 학점대체인증
# 학/석사 연계
# 교직과정
# Hi FIVE 전공교육과정
# 나노디그리
# 학과(전공)별 경력개발 로드맵
# 수업
# 열기
# 수강신청
# 성적
# 졸업사정
# 타대학 학점인정 및 교류
# 재이수 및 대체재이수
# 등록
# 열기
# 등록안내
# - 납부 및 반환규정
# - 가상계좌
# - 분할납부 안내
# - 등록금납부FAQ
# 등록일정
# 등록금 납부 고지서 및 교육비납입증명서 출력
# 학적
# 열기
# 휴/복학
# 재입학
# 편입학
# 소속변경 및 전공배정
# 수료 및 졸업
# 자퇴 및 제적
# 글로벌 우수역량 인증제
# 공지사항
# 열기
# 학사일정
# 교내 공지사항
# 교직원 채용공고
# 입찰공고
# 정보보호 게시판
# 개인정보 목적외 이용 제공
# 학사지원
# 글로벌 일류 대학, 한림대학교융·복합 교육을 통해 글로벌 인재를 양성합니다
# Vision
# 열기
# Vision 2030+
# 열기
# 비전과 목표
# 실행계획
# 추진 실적
# Hallym Vision 2030+ 보고서
# Vision 2030
# 열기
# 비전과 목표
# 핵심과제
# 추진 실적
# Hallym Vision 2030 보고서
# Vision&Action 2018~
# 열기
# 발전목표 및 핵심전략
# Action 2018~
# Vision 2018~ 체계도
# 한림의 미래
# 추진 실적
# 단과대학 및 스쿨별 비전
# 비전추진회의
# - 비전추진회의
# - 한림미래비전 포럼
# 한림 Vision & Action 2018~ 보고서
# Vision&Action 2016~2022
# 열기
# Vision 2016~2022 선포문
# 발전목표 및 핵심전략
# Action 2016~2022
# Vision 2016~2022 체계도
# 추진일정
# 변화된 모습(Vision 목표치)
# 단과대학별 비전
# 한림대학교 발전계획
# 산학협력 비전
# Action 2018~
# 열기
# 학사제도 선진화
# 교양교육 혁신
# 대학원 경쟁력 강화
# 특성화 연계 산학협력 고도화
# 산학협력 거점단지 조성
# 사회혁신과 디자인 역량 강화
# 국제화 역량 강화
# 글로벌 한국학 교육 기반 구축
# 글로벌 공동 연구 활성화
# 국제협력 선도 프로젝트 추진
# Campus Life 활성화
# Smart Campus 구축
# 행정서비스 전문화 및 효율화
# Vision
# 글로벌 일류 대학, 한림대학교융·복합 교육을 통해 글로벌 인재를 양성합니다
# 산학ㆍ연구
# 열기
# 산학협력
# 열기
# 산학협력 비전
# 산학협력 비전
# 산학협력 조직
# - 산학기획전략실
# - 산학협력본부
# - 창업지원본부
# - 산학연계교육원
# - 기업협력팀
# LINC 3.0 사업단
# 연구정보/특허 검색시스템
# 연구지원
# 열기
# 연구지원체계
# 연구활동
# 연구윤리센터
# - 연구진실성위원회
# - 동물실험윤리위원회
# 부설연구기관
# 열기
# 연구소 현황
# 인문대학 산하
# 사회과학대학 산하
# 경영대학 산하
# 자연과학대학 산하
# 정보과학대학 산하
# 의과대학 산하
# 간호대학 산하
# 글로벌융합대학 산하
# 미디어스쿨 산하
# 반도체·디스플레이스쿨 산하
# 미래융합스쿨 산하
# 글로벌협력대학원 산하
# 교책연구원 및 교책연구소
# 한림대학교 도헌학술원 산하
# 의료·바이오융합연구원 산하
# AI융합연구원 산하
# 임상치의학대학원 산하
# 산학ㆍ연구
# 글로벌 일류 대학을 향한 한림의중장기 비전과 연차별 실천 전략(Vision & Action 2016~2022 / Vision & Action 2018~)
# 글로벌 일류 대학, 한림대학교융·복합 교육을 통해 글로벌 인재를 양성합니다
# 전체메뉴 열기
# 대학소개
# 총장
# 인사말/프로필
# 연설 및 기고
# 동정
# 총장 메시지
# 교육이념과 인재상
# 교육이념
# 인재상
# 대학특성화
# 대학특성화
# 한림발자취
# 연혁
# 자료집
# 역대총장
# 개교 40주년 기념
# 일반현황
# 현황
# 조직도
# 규정집
# 예·결산공고/등록금심의위원회
# 대학평의원회
# 대학자체평가/인증
# 학교법인 현황
# 총장 업무추진비
# 기부금 현황
# 대학상징
# 교명
# 교가
# 상징
# UI
# 안전보건경영방침
# 안전보건경영방침
# 캠퍼스 안내
# 캠퍼스맵
# 한림비전관
# 캠퍼스 교육환경개선
# 학교오시는길
# 셔틀버스
# New Hallym 혁신본부
# D-1
# D-2
# D-3
# 행정부서/기관
# 교무처
# 연구처
# 학생처
# 행정지원처
# 대외협력처
# 입학처
# 부속기관
# 지식미디어센터
# 커뮤니티교육원
# 한림스포츠센터
# 학생생활관
# 정보전산원
# 고령사회종합연구원
# 실험동물센터
# 박물관
# 캠퍼스라이프 카운슬링센터
# 한림학보사
# 직속기구 및 기타기관
# 융합클러스터
# LINC 3.0 사업단
# 한림청소년자립지원관
# 영어교육센터
# 한국어교육센터
# 의사소통교육센터
# SW중심대학 사업단
# 에듀테크소프트랩 사업단
# 한림과학원
# 태동고전연구소
# 인권센터
# 생명윤리위원회
# 대경강원권역강원지역R-WeSET사업단
# 대학/대학원
# 인문대학
# 인문학부
# 영어영문학과
# 중국학과
# 일본학과
# 러시아학과
# 인문콘텐츠융합전공
# 사회과학대학
# 심리학과
# 사회학과
# 사회복지학부
# 정치행정학과
# 광고홍보학과
# 법학과
# 경제학과
# 청소년학
# 경영대학
# 경영학과
# 금융재무학과
# 스타트업비즈니스(융합)전공
# 자연과학대학
# 화학과
# 생명과학과
# 바이오메디컬학과
# 식품영양학과
# 환경생명공학과
# 언어청각학부
# 체육학과
# 바이오헬스케어융합전공
# 의과대학
# 의예·의학과
# 간호대학
# 간호학과
# 글로벌융합대학
# 글로벌학부
# 융합과학수사학과
# 융합인재학부
# 기후변화융합전공
# MICE기획경영전공
# 미디어스쿨
# 언론방송융합미디어 전공
# 디지털미디어콘텐츠 전공
# 반도체·디스플레이스쿨
# 반도체전공
# 디스플레이전공
# 정보과학대학
# 소프트웨어학부
# 인공지능융합학부
# 데이터사이언스학부
# 미래융합스쿨
# 디지털인문예술전공
# 글로벌협력전공
# 융합관광경영전공
# 의약신소재전공
# 융합신소재공학전공
# 마케팅커뮤니케이션테크놀로지융합전공
# 인터랙션디자인전공
# 공공인재융합전공
# 산학협력특성화대학
# 지능형 IoT 전공
# 사회혁신경영전공
# 건강돌봄디자인 전공
# 일송자유교양대학
# 자유교양전공
# 자기설계융합전공
# 실감미디어콘텐츠
# 출판기획및실무
# 콘텐츠IT-청각인지헬스케어
# 생명과학AI융합
# 금융경영커뮤니케이션
# 청각인지헬스케어 규제과학
# 글로벌관광커뮤니케이션
# 보험계리학
# 바이오벤처경영
# 대학원
# 일반대학원
# 온라인 대학원(창의미래융합대학원)
# 디자인·디지털 인문예술학과
# 디지털 마케팅학과
# 특수대학원
# 경영대학원
# 사회복지대학원
# 글로벌협력대학원
# 보건과학대학원
# 임상치의학대학원
# 간호대학원
# 입학
# 입학안내
# 학부
# 대학원
# 외국인
# 대학생활
# 프로그램
# 교수학습지원
# 장애학생지원
# 국제교류
# 취업지원
# 병무안내
# 학생활동
# 복지시설
# 장학제도
# 신입생장학금
# 재학생장학금
# 학자금 융자
# FAQ
# 캘린더
# 학사일정
# 주요일정
# 대학생활 안내
# 대학요람
# Hallym Census
# 미디어센터
# 한림투데이
# 교직원동정
# 칼럼 및 기고
# 포토갤러리
# 대학민원
# FAQ
# 증명서 발급
# 서식/신청서
# 교내홈페이지
# 학사지원
# 교육과정
# 복수전공
# 자기설계융합전공
# 학점대체인증
# 학/석사 연계
# 교직과정
# Hi FIVE 전공교육과정
# 나노디그리
# 학과(전공)별 경력개발 로드맵
# 수업
# 수강신청
# 성적
# 졸업사정
# 타대학 학점인정 및 교류
# 재이수 및 대체재이수
# 등록
# 등록안내
# 등록일정
# 등록금 납부 고지서 및 교육비납입증명서 출력
# 학적
# 휴/복학
# 재입학
# 편입학
# 소속변경 및 전공배정
# 수료 및 졸업
# 자퇴 및 제적
# 글로벌 우수역량 인증제
# 공지사항
# 학사일정
# 교내 공지사항
# 교직원 채용공고
# 입찰공고
# 정보보호 게시판
# 개인정보 목적외 이용 제공
# Vision
# Vision 2030+
# 비전과 목표
# 실행계획
# 추진 실적
# Hallym Vision 2030+ 보고서
# Vision 2030
# 비전과 목표
# 핵심과제
# 추진 실적
# Hallym Vision 2030 보고서
# Vision&Action 2018~
# 발전목표 및 핵심전략
# Action 2018~
# Vision 2018~ 체계도
# 한림의 미래
# 추진 실적
# 단과대학 및 스쿨별 비전
# 비전추진회의
# 한림 Vision & Action 2018~ 보고서
# Vision&Action 2016~2022
# Vision 2016~2022 선포문
# 발전목표 및 핵심전략
# Action 2016~2022
# Vision 2016~2022 체계도
# 추진일정
# 변화된 모습(Vision 목표치)
# 단과대학별 비전
# 한림대학교 발전계획
# 산학협력 비전
# Action 2018~
# 학사제도 선진화
# 교양교육 혁신
# 대학원 경쟁력 강화
# 특성화 연계 산학협력 고도화
# 산학협력 거점단지 조성
# 사회혁신과 디자인 역량 강화
# 국제화 역량 강화
# 글로벌 한국학 교육 기반 구축
# 글로벌 공동 연구 활성화
# 국제협력 선도 프로젝트 추진
# Campus Life 활성화
# Smart Campus 구축
# 행정서비스 전문화 및 효율화
# 산학ㆍ연구
# 산학협력
# 산학협력 비전
# 산학협력 비전
# 산학협력 조직
# LINC 3.0 사업단
# 연구정보/특허 검색시스템
# 연구지원
# 연구지원체계
# 연구활동
# 연구윤리센터
# 부설연구기관
# 연구소 현황
# 인문대학 산하
# 사회과학대학 산하
# 경영대학 산하
# 자연과학대학 산하
# 정보과학대학 산하
# 의과대학 산하
# 간호대학 산하
# 글로벌융합대학 산하
# 미디어스쿨 산하
# 반도체·디스플레이스쿨 산하
# 미래융합스쿨 산하
# 글로벌협력대학원 산하
# 교책연구원 및 교책연구소
# 한림대학교 도헌학술원 산하
# 의료·바이오융합연구원 산하
# AI융합연구원 산하
# 임상치의학대학원 산하
# 대학소개
# 대학/대학원
# 입학
# 대학생활
# 학사지원
# Vision
# 산학ㆍ연구
# 프로그램
# 장학제도
# 캘린더
# 대학생활 안내
# 미디어센터
# 대학민원
# 교수학습지원
# 장애학생지원
# 국제교류
# 취업지원
# 병무안내
# 학생활동
# 복지시설
# 대학생활
# 프로그램
# 열기
# 교수학습지원
# 장애학생지원
# 국제교류
# 취업지원
# 병무안내
# 학생활동
# 복지시설
# 장학제도
# 열기
# 신입생장학금
# 재학생장학금
# 학자금 융자
# FAQ
# 캘린더
# 열기
# 학사일정
# 주요일정
# 대학생활 안내
# 열기
# 대학요람
# Hallym Census
# 미디어센터
# 열기
# 한림투데이
# 교직원동정
# 칼럼 및 기고
# 포토갤러리
# 대학민원
# 열기
# FAQ
# 증명서 발급
# 서식/신청서
# 교내홈페이지
# 교수학습지원프로그램
# 한림 하이브리드 러닝 수업 모델
# 학습자 프로그램 안내
# 프로그램명
# 개요
# 홈페이지 링크
# 플립러닝(HA-FL)
# 온·오프라인 학습공간을 활용하여 Pre-Class, In-Class, Post-Class의 단계별 수업 구성으로 교수-학습자간 상호작용을 촉진하는 하이브리드 플립러닝 수업유형
# https://ctl.hallym.ac.kr/ko/model/hafl/intro
# 적응형학습(AI-AL)
# 인공지능(AI) 학습프로그램을 활용하여 학습자 수준에 맞는 문제 풀이를 통해 학습자 개개인의 학습데이터를 수집·분석하고 현재의 이해 및 지식수준을 측정하는 과정을 통해 학생 스스로 학습을 주도하는 수업유형
# https://ctl.hallym.ac.kr/ko/model/al/intro
# e+문제기반학습(e+PBL)
# 실제 생활의 맥락을 반영한 ‘문제 시나리오’를 중심으로 수업을 진행하며, 학생은 개별 학습과 협동학습을 통해 문제를 분석하고, ‘해결안(Solution)’을 도출하며 교수·학습법. 온·오프라인 학습공간을 모두 활용하는 수업유형
# https://ctl.hallym.ac.kr/ko/model/e_problem/intro
# e+프로젝트기반학습(e+PBL)
# 실제적인 프로젝트를 수행하는 과정을 중심으로 수업을 진행하며, 학생은 협동, 집중적인 탐구, 지식과 기술의 학습 등을 통해 ‘최종 산출물(Product) 혹은 보고서’를 만들어가는 교수·학습법으로 온·오프라인 학습공간을 모두 활용하는 수업유형
# https://ctl.hallym.ac.kr/ko/model/e_project/intro
# 교수지원 프로그램
# 학습자 프로그램 안내
# 프로그램명
# 개요
# 홈페이지 링크
# 교수법 코칭 프로그램
# 신임교원과 경력교원을 1:1로 매칭하여 신임교원이 대학체제에 잘 적응하도록 돕고, 수업 노하우를 공유함으로써 교수력을 향상하도록 지원하는 프로그램
# https://ctl.hallym.ac.kr/ko/professor/mentoring/intro
# 수업컨설팅
# 교수자가 수업을 촬영한 후 수업촬영 영상을 보고 수업활동에 대하여 자가진단해 보거나, 전문가의 분석 또는 1:1 컨설팅을 통하여 수업의 질을 개선할 수 있도록 지원하는 프로그램
# https://ctl.hallym.ac.kr/ko/professor/consulting/intro
# 신임교원 워크숍
# 신규 임용된 신임교원이 학교문화 및 조직의 이해를 도모하고, 교수활동 수월성을 향상하도록 지원하는 프로그램
# https://ctl.hallym.ac.kr/ko/professor/new_teacher/intro
# HCCC 교수 역량 강화 프로그램
# 우리 대학의 학생 중심교육 실현을 위한 한림(Hallym)창의(Creativity)·융합(Convergence)·상생(Collaboration) 핵심 가치 중심의 교수역량을 향상하도록 교수법과 관련된 다양한 주제의 전문가들을 초빙하여 전문화된 지식과 정보를 제공하는 프로그램
# https://ctl.hallym.ac.kr/ko/professor/workshop/intro
# 우수 교육 사례 발굴 프로젝트
# 지식 전달 강의 중심이 아닌 강의실 안팎에서 이루어지는 교수·학습 활동까지 아우르는 우수 교육 사례 발굴을 통해 우리대학 교육 경쟁력을 강화하는 프로그램
# https://ctl.hallym.ac.kr/ko/professor/great_project/intro
# 강의개선 교수력 강화 프로그램
# 교수자 맞춤형 콘텐츠 제작 및 제공을 통한 세분화 지원으로 교원의 수업 역량을 강화하고, 강의평가 하위교원의 지속적인 강의 개선 노력 도모를 지원하는 프로그램
# https://ctl.hallym.ac.kr/ko/professor/award/intro
# Best Teacher Award
# 학생 중심 교육을 통해 선진인재 양성을 실현하는 교육 우수교원 선발 프로그램
# https://ctl.hallym.ac.kr/ko/professor/award/intro
# Teaching Tips
# 교수 지원을 위한 강의 및 학습에 유용하게 활용할 수 있는 교수법 Tips 발간을 통해 교수력 증진을 도모하는 프로그램
# https://ctl.hallym.ac.kr/ko/professor/tips/intro
# 학습지원 프로그램
# 교육환경 지원 안내
# 프로그램명
# 개요
# 홈페이지 링크
# 상생러닝디딤돌
# 직전 학기 학사경고자를 대상으로 대학 생활에 필요한 정보 제공과 상담(멘토링)을 통한 대학생활 적응 및 학습력 제고를 위한 프로그램
# https://ctl.hallym.ac.kr/ko/student/didimdol/intro
# 한림멘토링
# 우수한 성적의 학생을 멘토로 선발하여 학과 선후배간 매칭된 그룹의 학습활동을 통한 멘티의 대학생활 적응과 전공 교과목 학습력 향상을 위한 프로그램
# https://ctl.hallym.ac.kr/ko/student/mentoring/intro
# 한림학습진단 프로그램
# 학습유형 검사 및 분석을 통해 자신의 학습 장/단점 파악하고 신입생부터 자신만의 학습/진로설계를 할 수 있는 기회 제공하는 프로그램
# https://ctl.hallym.ac.kr/ko/student/diagnosis/intro
# 유앤아이생애설계
# 학생의 학습 유형 및 성격 유형을 분석하여, 학생이 겪고 있는 주문제의 해결책을 제시하며, 해결책 기반으로 학생과 전문가가 학생 맞춤형 활동들을 통하여 학습/동기/진로를 설계하는 프로그램
# https://ctl.hallym.ac.kr/ko/student/consulting/intro
# 좋은수업 추천하기 공모전
# 본인이 해당 학기에 수강하고 있는 수업 중 우수한 수업을 추천함으로써, 교수님들과 학생들에게 다양한 수업전략 및 강좌에 대한 정보를 공유하는 프로그램
# https://ctl.hallym.ac.kr/ko/student/contest/intro
# HCCC 학습 역량 강화 프로그램
# 한림(Hallym) 창의(Creativity)·융합(Convergence)·상생(Collaboration) 핵심 가치의 학습 역량 강화를 위해 다양한 대학생활 설계 및 자기주도적 학습전략 특강을 제공하는 프로그램
# https://ctl.hallym.ac.kr/ko/student/tighten/intro
# AI & Human 프로젝트
# AI 학습프로그램을 통한 학습 활동으로 인공지능(AI) 학습프로그램 활용과 창의적 학습 4P(Project, Passion, Peers, Play) 원리를 기반하여 창의 인재 & 자기주도 학습자를 양성 하는 프로그램
# https://ctl.hallym.ac.kr/ko/student/AI/intro
# Learning Tips
# 다양한 학습력 강화 정보를 담은 Learning Tips 공유로 효과적인 학습 전략, 학습 점검 및 진단에 활용하여 학습법 개선을 도모하는 프로그램
# https://ctl.hallym.ac.kr/ko/student/tips/intro
# 재학생
# 교수
# 직원
# 수험생
# 동문
# 방문객
# 다음
# 학생정보시스템
# SmartLEAD
# 일송기념도서관
# 한림Q&A
# 장학안내
# 셔틀버스
# 학생생활관
# 한림 BeCome
# 한림 신문고
# 인터넷증명발급
# 취업진로지원센터
# 산학협력통합플랫폼
# 다음
# 통합정보시스템
# SmartLEAD
# 전자출결시스템
# 한림그룹웨어
# 연구행정통합시스템
# 산학협력통합플랫폼
# 채용시스템
# 행정부서/기관
# 교내시설물이용안내
# 발전기금
# 대학알리미
# 규정집
# 다음
# 통합정보시스템
# 한림그룹웨어
# 규정집
# 교직원채용
# 발전기금
# 산학협력통합플랫폼
# 행정부서/기관
# 부속기관
# 한림 신문고
# 공지사항
# 주요일정
# 대학알리미
# 다음
# 입학안내
# 신입생장학금
# 대학알리미
# 대학생활안내
# 한림Vision
# 캠퍼스맵
# 학사일정
# 일송기념도서관
# 학생생활관
# 한림발자취
# 한림비전관
# 다음
# 발전기금
# 총동문회
# 인터넷증명발급
# 한림발자취
# 한림투데이
# 재입학
# 한림비전관
# 다음
# 캠퍼스맵
# 오시는길
# 대학현황
# 한림발자취
# 한림Vision
# 한림투데이
# 교직원채용
# 입찰공고
# 행정부서/기관
# 커뮤니티교육원
# 일송아트홀
# 산학협력통합플랫폼
# 개인정보처리방침
# 대학알리미
# 이메일주소 무단수집거부
# 주요민원연락처
# 사이트맵
# 교육할인스토어
# 입찰공고
# 방문자 시스템
# 캠퍼스맵
# 주요사이트
# 취업진로지원센터
# 학생생활관
# 커뮤니티교육원
# 일송아트홀
# 한림대학교의료원
# 찾아오시는 길
# 국제학생증신청
# 한림대학교 LINC 3.0 사업단
# 캠퍼스라이프카운슬링센터
# 산학협력단
# 산학협력통합플랫폼
# 소프트웨어중심대학
# 교육혁신센터
# 방문자 시스템
# Hi FIVE 전공교육과정
# 의사소통교육센터
# Hallym 진로취업 Open 캠퍼스
# (24252)강원특별자치도 춘천시 한림대학길 1
# 대표 033-248-1000
# 입학안내 033-248-1301~3
# 팩스 033-248-3333
# COPYRIGHT© 2016 HALLYM UNIVERSITY. ALL RIGHTS RESERVED.
# TOP

# %%
# Faiss 인덱스 생성
dimension = len(embeddings[0])
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings))

# %%
def rag_query(query, k=3):
    query_embedding = get_embedding(query)
    if query_embedding is None:
        return "Failed to generate query embedding."
    
    _, indices = index.search(np.array([query_embedding]), k)
    
    context = "\n".join([documents[i] for i in indices[0]])
    
    # 프롬프트에 한국말로 결과값 나오도록 설정
    # 소장님이 제안해주신대로 주어진 정보 내에서만 답변 해줄 수 있을지 고려
    prompt = f"""
    Context: {context}

    질문: {query}

    지시사항:
    1. 주어진 컨텍스트 정보만을 사용하여 답변하세요.
    2. 정확한 정보가 없다면 "이 정보는 주어진 컨텍스트에 없습니다"라고 말하세요.
    3. 답변은 중요 내용 위주로 간결하게 작성하세요.

    답변:
    """
    
#     # Few-shot 예제와 함께 프롬프트 생성
#     # 실행해봤으나 이 예제에 결과가 영향을 너무 많이 받음을 확인
#     few_shot_example = """
#     질문: 도서관 운영 시간은 어떻게 되나요?
#     답변: 도서관은 평일 오전 9시부터 오후 6시까지 운영됩니다. 주말에는 오전 10시부터 오후 5시까지 개방합니다. 공휴일에는 휴관입니다.
    
#     질문: {query}
#     답변:
#     """
#     prompt = f"Context: {context}\n\n{few_shot_example}"
    
    return generate_response(prompt)

# %%
# 사용 예시
query = "적응형학습이 뭐야?"
response = rag_query(query)
print(response)
# Out:
# 적응형 학습이란 학생의 개별적인 요구, 선호도 및 학습 속도에 기반하여 교육 자료를 조정하는 학습 접근 방식을 말합니다. 이는 학생이 자신의 학습 속도대로 진행할 수 있도록 개인화된 학습 경험을 제공하며, 강점과 약점에 따라 콘텐츠를 맞춤화함으로써 학생들이 더 효과적으로 배울 수 있도록 돕습니다. 적응형 학습은 학생들이 특정 개념이나 기술을 마스터할 때까지 추가적인 지원과 자원을 제공할 수 있게 함으로써 개별 학생의 필요에 맞추어 교육 자료를 조정합니다. 주어진 컨텍스트 정보에는 적응형 학습에 대한 구체적인 언급이 없습니다.

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl
# Out:
# Looking in indexes: https://download.pytorch.org/whl
# Requirement already satisfied: torch in ./anaconda3/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: torchvision in ./anaconda3/lib/python3.11/site-packages (0.19.0)
# Requirement already satisfied: torchaudio in ./anaconda3/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: filelock in ./anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./anaconda3/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in ./anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in ./anaconda3/lib/python3.11/site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in ./anaconda3/lib/python3.11/site-packages (from torch) (2023.4.0)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./anaconda3/lib/python3.11/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in ./anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.2.1)

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %% [markdown]
# **임베딩한 데이터가 제대로 반영되지 않은 이유:**
#
# 1. 임베딩 품질: get_embedding 함수가 제대로 작동하지 않아 모든 문서에 대해 유사한 임베딩을 생성했을 수 있음
# 2. 인덱스 문제: Faiss 인덱스가 제대로 생성되지 않았거나, 검색이 제대로 작동하지 않을 수 있음
# 3. 컨텍스트 선택: k=3으로 설정되어 있어, 가장 유사한 3개의 문서만 선택됩니다. 이 값이 너무 작아 관련 문서가 선택되지 않았을 수 있음
# 4. 모델 응답: OLLAMA 모델이 주어진 컨텍스트를 무시하고 자체 지식에 기반하여 응답했을 수 있음
# 5. 데이터 처리 오류: 파일 읽기나 전처리 과정에서 오류가 발생해 일부 문서가 제대로 처리되지 않았을 수 있음

# %% [markdown]
# **해결해야 할 문제 8/19 마무리**
# 1. 답안이 항상 일정하게 나오지 않는다 ✔️
# 2. 그림 파일 임베딩이 제대로 안 됨 ✔️
# 3. 임베딩 안 되는 파일들 이유 찾아보기 ✔️
# 4. 효과적으로 임베딩하는 방법 찾아보기
# 5. 임베딩한 내용이 효과적으로 답안에 반영되도록 하는 방법 알아보기 🔺
#    (지금은 자체적으로 답변해주는 경우도 많은 것 같음, 정확하지 않은 정보는 조금이라도 답변을 해주려는게 오히려 위험한 것 같기도 하다)
# 6. 형식 조정할 수 있는지 template 구조 살펴보기

# %% [markdown]
# **해결해야 할 문제 8/20 마무리**
# 1. 홈페이지 내용을 웹크롤링
# 2. 학사과정 페이지에 경영대학 파일 임베딩 (pdf), **표**나(페이지는 잘 가져와지는지) 그림은 어떻게 임베딩 하는지 방법 찾아보고, 결과 확인
#    EEVE랑 결과 값이 연동?이 되는지 확인해보기, 구조 같은지
# 3. 웹페이지 한번에 가져오는 웹크롤링 라이브러리 확인
